# %%
import h5py 
import numpy as np
import os

# %%
grasp_file_path = '/mnt/tars_data/multi_finger_sim_data_6_6/grasp_data.h5'
grasp_data_file = h5py.File(grasp_file_path, 'r')

# %%
grasps_num = grasp_data_file['total_grasps_num'][()]
max_object_id = grasp_data_file['max_object_id'][()]
print grasps_num, max_object_id
# Out:
# 967 114

# %%
def find_pcd_file(data_path, grasp_data_file, object_id, grasp_id, object_name):
    pcd_file_name = object_id + '_' + object_name + \
    '_grasp_' + str(grasp_id) + '.pcd'
    pcd_file_path = data_path + 'pcd/' + pcd_file_name
    object_world_seg_pose_key = object_id + '_grasp_' + str(grasp_id) + '_object_world_seg_pose'
    object_world_seg_pose = grasp_data_file[object_world_seg_pose_key][()]
    
    #print pcd_file_path
    #print os.path.isfile(pcd_file_path)
    if not os.path.isfile(pcd_file_path):
        #print 'HAHA'
        pcd_file_name = None
        for i in xrange(1, 3):
            prev_pcd_file_name = object_id + '_' + object_name + \
                    '_grasp_' + str(grasp_id - i) + '.pcd' 
            prev_pcd_file_path = data_path + 'pcd/' + prev_pcd_file_name          
            #print prev_pcd_file_name

            if os.path.isfile(prev_pcd_file_path):
#                 grasp_pose_key = object_id + '_grasp_' + str(grasp_id - i)  + '_object_world_pose'
#                 grasp_pose_prev = grasp_data_file[grasp_pose_key][()]
                object_world_seg_pose_key = object_id + '_grasp_' + str(grasp_id - i) + '_object_world_seg_pose'
                object_world_pose_prev = grasp_data_file[object_world_seg_pose_key][()]
                #print grasp_pose_prev
                #if np.array_equal(grasp_pose_prev, grasp_pose):
                if np.allclose(object_world_pose_prev, object_world_seg_pose):
                    print 'object pose equal'
                    pcd_file_name = prev_pcd_file_name
                    break
                print 'object pose not equal'
                #print grasp_pose - grasp_pose_prev
    return pcd_file_name

# %%
# For each grasp, extract the grasp config, grasp label, and generate voxel
# Also need to record the object id, grasp id, and object_name of each grasp.

# Notice: the max grasp id of one object could be 19 (0-19) + 3 = 22, because we try 
# 3 grasp heuristic grasp trials for each object pose.
max_grasps_per_obj = 23
total_grasps_num = 0
suc_grasps_num = 0
top_grasps_num = 0
top_suc_grasps_num = 0
save_visual_data_pre_path = '/mnt/tars_data/multi_finger_sim_data_6_6/'
for obj_id in xrange(max_object_id + 1):
    object_id = 'object_' + str(obj_id)
    object_name = grasp_data_file[object_id + '_name'][()]
    #print object_name
    for grasp_id in xrange(max_grasps_per_obj):
        #print grasp_id
        object_grasp_id = object_id + '_grasp_' + str(grasp_id)
        grasp_label_key = object_grasp_id + '_grasp_label'
        if grasp_label_key in grasp_data_file:
            grasp_label = grasp_data_file[grasp_label_key][()]
            #print grasp_label
            total_grasps_num += 1
            suc_grasps_num += grasp_label
            object_world_seg_pose_key = object_grasp_id + '_object_world_seg_pose'
            object_world_seg_pose = grasp_data_file[object_world_seg_pose_key][()]
            preshape_js_position_key = object_grasp_id + '_preshape_joint_state_position'
            preshape_js = grasp_data_file[preshape_js_position_key][()]
            palm_world_pose_key = object_grasp_id + '_preshape_palm_world_pose'
            palm_world_pose = grasp_data_file[palm_world_pose_key][()]
            top_grasp_key = object_grasp_id + '_top_grasp'
            top_grasp = grasp_data_file[top_grasp_key][()]
            top_grasps_num += top_grasp
            if grasp_label == 1 and top_grasp:
                top_suc_grasps_num += 1
            #print object_world_seg_pose, preshape_js, palm_world_pose
            
#             pcd_file_path = save_visual_data_pre_path + \
#             'pcd/' + 'object_' + str(obj_id) + '_' + str(object_name) + \
#             '_grasp_' + str(grasp_id) + '.pcd'
#             print pcd_file_path
#             print os.path.isfile(pcd_file_path)
            pcd_file_path_found = find_pcd_file(save_visual_data_pre_path, grasp_data_file,
                                                object_id, grasp_id, object_name)
            print pcd_file_path_found
            #print grasp_id
#             if pcd_file_path_found is None:
#                 break
    #break
#     if pcd_file_path_found is None:
#         break
            

print total_grasps_num, suc_grasps_num, top_grasps_num, top_suc_grasps_num
# Out:
# object_0_3m_high_tack_spray_adhesive_grasp_0.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_0.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_0.pcd
# object_0_3m_high_tack_spray_adhesive_grasp_3.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_3.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_3.pcd
# object_0_3m_high_tack_spray_adhesive_grasp_6.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_6.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_6.pcd
# object_0_3m_high_tack_spray_adhesive_grasp_9.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_9.pcd
# object_0_3m_high_tack_spray_adhesive_grasp_11.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_11.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_11.pcd
# object_0_3m_high_tack_spray_adhesive_grasp_14.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_14.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_14.pcd
# object_0_3m_high_tack_spray_adhesive_grasp_17.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_17.pcd
# object pose equal
# object_0_3m_high_tack_spray_adhesive_grasp_17.pcd
# object_1_advil_liqui_gels_grasp_0.pcd
# object_1_advil_liqui_gels_grasp_1.pcd
# object pose equal
# object_1_advil_liqui_gels_grasp_1.pcd
# object_1_advil_liqui_gels_grasp_3.pcd
# object_2_aunt_jemima_original_syrup_grasp_0.pcd
# object pose equal
# object_2_aunt_jemima_original_syrup_grasp_0.pcd
# object pose equal
# object_2_aunt_jemima_original_syrup_grasp_0.pcd
# object_2_aunt_jemima_original_syrup_grasp_3.pcd
# object_2_aunt_jemima_original_syrup_grasp_4.pcd
# object_2_aunt_jemima_original_syrup_grasp_5.pcd
# object pose equal
# object_2_aunt_jemima_original_syrup_grasp_5.pcd
# object_2_aunt_jemima_original_syrup_grasp_7.pcd
# object pose equal
# object_2_aunt_jemima_original_syrup_grasp_7.pcd
# object pose equal
# object_2_aunt_jemima_original_syrup_grasp_7.pcd
# object_2_aunt_jemima_original_syrup_grasp_10.pcd
# object pose equal
# object_2_aunt_jemima_original_syrup_grasp_10.pcd
# object pose equal
# object_2_aunt_jemima_original_syrup_grasp_10.pcd
# object_2_aunt_jemima_original_syrup_grasp_13.pcd
# object_2_aunt_jemima_original_syrup_grasp_14.pcd
# object pose equal
# object_2_aunt_jemima_original_syrup_grasp_14.pcd
# object_2_aunt_jemima_original_syrup_grasp_16.pcd
# object pose equal
# object_2_aunt_jemima_original_syrup_grasp_16.pcd
# object_2_aunt_jemima_original_syrup_grasp_18.pcd
# object pose equal
# object_2_aunt_jemima_original_syrup_grasp_18.pcd
# object_3_bai5_sumatra_dragonfruit_grasp_0.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_0.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_0.pcd
# object_3_bai5_sumatra_dragonfruit_grasp_3.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_3.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_3.pcd
# object_3_bai5_sumatra_dragonfruit_grasp_6.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_6.pcd
# object_3_bai5_sumatra_dragonfruit_grasp_8.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_8.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_8.pcd
# object_3_bai5_sumatra_dragonfruit_grasp_11.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_11.pcd
# object_3_bai5_sumatra_dragonfruit_grasp_13.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_13.pcd
# object_3_bai5_sumatra_dragonfruit_grasp_15.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_15.pcd
# object_3_bai5_sumatra_dragonfruit_grasp_17.pcd
# object_3_bai5_sumatra_dragonfruit_grasp_18.pcd
# object_3_bai5_sumatra_dragonfruit_grasp_19.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_19.pcd
# object pose equal
# object_3_bai5_sumatra_dragonfruit_grasp_19.pcd
# object_4_band_aid_clear_strips_grasp_0.pcd
# object_4_band_aid_clear_strips_grasp_1.pcd
# object_4_band_aid_clear_strips_grasp_2.pcd
# object_4_band_aid_clear_strips_grasp_3.pcd
# object_4_band_aid_clear_strips_grasp_4.pcd
# object_4_band_aid_clear_strips_grasp_5.pcd
# object pose equal
# object_4_band_aid_clear_strips_grasp_5.pcd
# object pose equal
# object_4_band_aid_clear_strips_grasp_5.pcd
# object_5_band_aid_sheer_strips_grasp_0.pcd
# object_5_band_aid_sheer_strips_grasp_1.pcd
# object pose equal
# object_5_band_aid_sheer_strips_grasp_1.pcd
# object_5_band_aid_sheer_strips_grasp_3.pcd
# object_6_blue_clover_baby_toy_grasp_0.pcd
# object pose equal
# object_6_blue_clover_baby_toy_grasp_0.pcd
# object_6_blue_clover_baby_toy_grasp_2.pcd
# object_6_blue_clover_baby_toy_grasp_3.pcd
# object_6_blue_clover_baby_toy_grasp_4.pcd
# object_6_blue_clover_baby_toy_grasp_5.pcd
# object_6_blue_clover_baby_toy_grasp_6.pcd
# object_7_bumblebee_albacore_grasp_0.pcd
# object_7_bumblebee_albacore_grasp_1.pcd
# object_7_bumblebee_albacore_grasp_2.pcd
# object_7_bumblebee_albacore_grasp_3.pcd
# object pose equal
# object_7_bumblebee_albacore_grasp_3.pcd
# object_8_campbells_chicken_noodle_soup_grasp_0.pcd
# object_8_campbells_chicken_noodle_soup_grasp_1.pcd
# object_8_campbells_chicken_noodle_soup_grasp_2.pcd
# object_8_campbells_chicken_noodle_soup_grasp_3.pcd
# object_9_campbells_soup_at_hand_creamy_tomato_grasp_0.pcd
# object pose equal
# object_9_campbells_soup_at_hand_creamy_tomato_grasp_0.pcd
# object_9_campbells_soup_at_hand_creamy_tomato_grasp_2.pcd
# object_9_campbells_soup_at_hand_creamy_tomato_grasp_3.pcd
# object_9_campbells_soup_at_hand_creamy_tomato_grasp_4.pcd
# object pose equal
# object_9_campbells_soup_at_hand_creamy_tomato_grasp_4.pcd
# object_9_campbells_soup_at_hand_creamy_tomato_grasp_6.pcd
# object_10_canon_ack_e10_box_grasp_0.pcd
# object pose equal
# object_10_canon_ack_e10_box_grasp_0.pcd
# object_10_canon_ack_e10_box_grasp_2.pcd
# object_10_canon_ack_e10_box_grasp_3.pcd
# object pose equal
# object_10_canon_ack_e10_box_grasp_3.pcd
# object_10_canon_ack_e10_box_grasp_5.pcd
# object_10_canon_ack_e10_box_grasp_6.pcd
# object pose equal
# object_10_canon_ack_e10_box_grasp_6.pcd
# object_10_canon_ack_e10_box_grasp_8.pcd
# object pose equal
# object_10_canon_ack_e10_box_grasp_8.pcd
# object_10_canon_ack_e10_box_grasp_10.pcd
# object pose equal
# object_10_canon_ack_e10_box_grasp_10.pcd
# object_10_canon_ack_e10_box_grasp_12.pcd
# object pose equal
# object_10_canon_ack_e10_box_grasp_12.pcd
# object_11_cheez_it_white_cheddar_grasp_0.pcd
# object pose equal
# object_11_cheez_it_white_cheddar_grasp_0.pcd
# object_12_chewy_dipps_chocolate_chip_grasp_0.pcd
# object_12_chewy_dipps_chocolate_chip_grasp_1.pcd
# object_12_chewy_dipps_chocolate_chip_grasp_2.pcd
# object_12_chewy_dipps_chocolate_chip_grasp_3.pcd
# object_12_chewy_dipps_chocolate_chip_grasp_4.pcd
# object_12_chewy_dipps_chocolate_chip_grasp_5.pcd
# object_13_chewy_dipps_peanut_butter_grasp_0.pcd
# object_13_chewy_dipps_peanut_butter_grasp_1.pcd
# object_13_chewy_dipps_peanut_butter_grasp_2.pcd
# object_13_chewy_dipps_peanut_butter_grasp_3.pcd
# object_14_cholula_chipotle_hot_sauce_grasp_0.pcd
# object_14_cholula_chipotle_hot_sauce_grasp_1.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_1.pcd
# object_14_cholula_chipotle_hot_sauce_grasp_3.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_3.pcd
# object_14_cholula_chipotle_hot_sauce_grasp_5.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_5.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_5.pcd
# object_14_cholula_chipotle_hot_sauce_grasp_8.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_8.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_8.pcd
# object_14_cholula_chipotle_hot_sauce_grasp_11.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_11.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_11.pcd
# object_14_cholula_chipotle_hot_sauce_grasp_14.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_14.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_14.pcd
# object_14_cholula_chipotle_hot_sauce_grasp_17.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_17.pcd
# object_14_cholula_chipotle_hot_sauce_grasp_19.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_19.pcd
# object pose equal
# object_14_cholula_chipotle_hot_sauce_grasp_19.pcd
# object_15_cinnamon_toast_crunch_grasp_0.pcd
# object pose equal
# object_15_cinnamon_toast_crunch_grasp_0.pcd
# object_15_cinnamon_toast_crunch_grasp_2.pcd
# object pose equal
# object_15_cinnamon_toast_crunch_grasp_2.pcd
# object_16_clif_crunch_chocolate_chip_grasp_0.pcd
# object_16_clif_crunch_chocolate_chip_grasp_1.pcd
# object_16_clif_crunch_chocolate_chip_grasp_2.pcd
# object_16_clif_crunch_chocolate_chip_grasp_3.pcd
# object_16_clif_crunch_chocolate_chip_grasp_4.pcd
# object_16_clif_crunch_chocolate_chip_grasp_5.pcd
# object pose equal
# object_16_clif_crunch_chocolate_chip_grasp_5.pcd
# object pose equal
# object_16_clif_crunch_chocolate_chip_grasp_5.pcd
# object_16_clif_crunch_chocolate_chip_grasp_8.pcd
# object_17_clif_crunch_peanut_butter_grasp_0.pcd
# object_17_clif_crunch_peanut_butter_grasp_1.pcd
# object_17_clif_crunch_peanut_butter_grasp_2.pcd
# object_18_clif_crunch_white_chocolate_macademia_nut_grasp_0.pcd
# object_18_clif_crunch_white_chocolate_macademia_nut_grasp_1.pcd
# object_18_clif_crunch_white_chocolate_macademia_nut_grasp_2.pcd
# object_18_clif_crunch_white_chocolate_macademia_nut_grasp_3.pcd
# object_18_clif_crunch_white_chocolate_macademia_nut_grasp_4.pcd
# object_18_clif_crunch_white_chocolate_macademia_nut_grasp_5.pcd
# object_19_clif_zbar_chocolate_brownie_grasp_0.pcd
# object_19_clif_zbar_chocolate_brownie_grasp_1.pcd
# object_19_clif_zbar_chocolate_brownie_grasp_2.pcd
# object pose equal
# object_19_clif_zbar_chocolate_brownie_grasp_2.pcd
# object_19_clif_zbar_chocolate_brownie_grasp_4.pcd
# object pose equal
# object_19_clif_zbar_chocolate_brownie_grasp_4.pcd
# object_19_clif_zbar_chocolate_brownie_grasp_6.pcd
# object_20_clif_z_bar_chocolate_chip_grasp_0.pcd
# object_20_clif_z_bar_chocolate_chip_grasp_1.pcd
# object_21_coffee_mate_french_vanilla_grasp_0.pcd
# object pose equal
# object_21_coffee_mate_french_vanilla_grasp_0.pcd
# object pose equal
# object_21_coffee_mate_french_vanilla_grasp_0.pcd
# object_21_coffee_mate_french_vanilla_grasp_3.pcd
# object_21_coffee_mate_french_vanilla_grasp_4.pcd
# object_21_coffee_mate_french_vanilla_grasp_5.pcd
# object pose equal
# object_21_coffee_mate_french_vanilla_grasp_5.pcd
# object_21_coffee_mate_french_vanilla_grasp_7.pcd
# object pose equal
# object_21_coffee_mate_french_vanilla_grasp_7.pcd
# object_21_coffee_mate_french_vanilla_grasp_9.pcd
# object pose equal
# object_21_coffee_mate_french_vanilla_grasp_9.pcd
# object pose equal
# object_21_coffee_mate_french_vanilla_grasp_9.pcd
# object_21_coffee_mate_french_vanilla_grasp_12.pcd
# object pose equal
# object_21_coffee_mate_french_vanilla_grasp_12.pcd
# object_21_coffee_mate_french_vanilla_grasp_14.pcd
# object_22_colgate_cool_mint_grasp_0.pcd
# object_22_colgate_cool_mint_grasp_1.pcd
# object_22_colgate_cool_mint_grasp_2.pcd
# object_22_colgate_cool_mint_grasp_3.pcd
# object_22_colgate_cool_mint_grasp_4.pcd
# object_22_colgate_cool_mint_grasp_5.pcd
# object pose equal
# object_22_colgate_cool_mint_grasp_5.pcd
# object_22_colgate_cool_mint_grasp_7.pcd
# object_22_colgate_cool_mint_grasp_8.pcd
# object_23_crayola_24_crayons_grasp_0.pcd
# object pose equal
# object_23_crayola_24_crayons_grasp_0.pcd
# object_23_crayola_24_crayons_grasp_2.pcd
# object_23_crayola_24_crayons_grasp_3.pcd
# object_23_crayola_24_crayons_grasp_4.pcd
# object_23_crayola_24_crayons_grasp_5.pcd
# object_23_crayola_24_crayons_grasp_6.pcd
# object_23_crayola_24_crayons_grasp_7.pcd
# object_24_nature_valley_crunchy_oats_n_honey_grasp_0.pcd
# object_24_nature_valley_crunchy_oats_n_honey_grasp_1.pcd
# object_24_nature_valley_crunchy_oats_n_honey_grasp_2.pcd
# object_24_nature_valley_crunchy_oats_n_honey_grasp_3.pcd
# object_24_nature_valley_crunchy_oats_n_honey_grasp_4.pcd
# object pose equal
# object_24_nature_valley_crunchy_oats_n_honey_grasp_4.pcd
# object_25_nature_valley_crunchy_variety_pack_grasp_0.pcd
# object_25_nature_valley_crunchy_variety_pack_grasp_1.pcd
# object_25_nature_valley_crunchy_variety_pack_grasp_2.pcd
# object_26_nature_valley_gluten_free_roasted_nut_crunch_almond_crunch_grasp_0.pcd
# object_26_nature_valley_gluten_free_roasted_nut_crunch_almond_crunch_grasp_1.pcd
# object_26_nature_valley_gluten_free_roasted_nut_crunch_almond_crunch_grasp_2.pcd
# object_27_nature_valley_granola_thins_dark_chocolate_grasp_0.pcd
# object_27_nature_valley_granola_thins_dark_chocolate_grasp_1.pcd
# object_27_nature_valley_granola_thins_dark_chocolate_grasp_2.pcd
# object_28_nature_valley_soft_baked_oatmeal_squares_cinnamon_brown_sugar_grasp_0.pcd
# object_28_nature_valley_soft_baked_oatmeal_squares_cinnamon_brown_sugar_grasp_1.pcd
# object_29_nature_valley_soft_baked_oatmeal_squares_peanut_butter_grasp_0.pcd
# object pose equal
# object_29_nature_valley_soft_baked_oatmeal_squares_peanut_butter_grasp_0.pcd
# object_29_nature_valley_soft_baked_oatmeal_squares_peanut_butter_grasp_2.pcd
# object_29_nature_valley_soft_baked_oatmeal_squares_peanut_butter_grasp_3.pcd
# object_30_nature_valley_sweet_and_salty_nut_almond_grasp_0.pcd
# object_30_nature_valley_sweet_and_salty_nut_almond_grasp_1.pcd
# object_30_nature_valley_sweet_and_salty_nut_almond_grasp_2.pcd
# object_30_nature_valley_sweet_and_salty_nut_almond_grasp_3.pcd
# object_30_nature_valley_sweet_and_salty_nut_almond_grasp_4.pcd
# object_30_nature_valley_sweet_and_salty_nut_almond_grasp_5.pcd
# object_31_nature_valley_sweet_and_salty_nut_cashew_grasp_0.pcd
# object_32_nature_valley_sweet_and_salty_nut_peanut_grasp_0.pcd
# object_32_nature_valley_sweet_and_salty_nut_peanut_grasp_1.pcd
# object_32_nature_valley_sweet_and_salty_nut_peanut_grasp_2.pcd
# object_33_nature_valley_sweet_and_salty_nut_roasted_mix_nut_grasp_0.pcd
# object_33_nature_valley_sweet_and_salty_nut_roasted_mix_nut_grasp_1.pcd
# object_33_nature_valley_sweet_and_salty_nut_roasted_mix_nut_grasp_2.pcd
# object_33_nature_valley_sweet_and_salty_nut_roasted_mix_nut_grasp_3.pcd
# object_34_nice_honey_roasted_almonds_grasp_0.pcd
# object_34_nice_honey_roasted_almonds_grasp_1.pcd
# object_35_nutrigrain_apple_cinnamon_grasp_0.pcd
# object_36_nutrigrain_blueberry_grasp_0.pcd
# object_36_nutrigrain_blueberry_grasp_1.pcd
# object_37_nutrigrain_cherry_grasp_0.pcd
# object_37_nutrigrain_cherry_grasp_1.pcd
# object_37_nutrigrain_cherry_grasp_2.pcd
# object_38_nutrigrain_chotolatey_crunch_grasp_0.pcd
# object_39_pop_tarts_strawberry_grasp_0.pcd
# object pose equal
# object_39_pop_tarts_strawberry_grasp_0.pcd
# object_39_pop_tarts_strawberry_grasp_2.pcd
# object pose equal
# object_39_pop_tarts_strawberry_grasp_2.pcd
# object_39_pop_tarts_strawberry_grasp_4.pcd
# object pose equal
# object_39_pop_tarts_strawberry_grasp_4.pcd
# object_39_pop_tarts_strawberry_grasp_6.pcd
# object_39_pop_tarts_strawberry_grasp_7.pcd
# object_39_pop_tarts_strawberry_grasp_8.pcd
# object pose equal
# object_39_pop_tarts_strawberry_grasp_8.pcd
# object_39_pop_tarts_strawberry_grasp_10.pcd
# object_39_pop_tarts_strawberry_grasp_11.pcd
# object_39_pop_tarts_strawberry_grasp_12.pcd
# object_39_pop_tarts_strawberry_grasp_13.pcd
# object_39_pop_tarts_strawberry_grasp_14.pcd
# object_40_pringles_bbq_grasp_0.pcd
# object pose equal
# object_40_pringles_bbq_grasp_0.pcd
# object_40_pringles_bbq_grasp_2.pcd
# object_40_pringles_bbq_grasp_3.pcd
# object pose equal
# object_40_pringles_bbq_grasp_3.pcd
# object pose equal
# object_40_pringles_bbq_grasp_3.pcd
# object_40_pringles_bbq_grasp_6.pcd
# object pose equal
# object_40_pringles_bbq_grasp_6.pcd
# object pose equal
# object_40_pringles_bbq_grasp_6.pcd
# object_41_progresso_new_england_clam_chowder_grasp_0.pcd
# object_41_progresso_new_england_clam_chowder_grasp_1.pcd
# object pose equal
# object_41_progresso_new_england_clam_chowder_grasp_1.pcd
# object_41_progresso_new_england_clam_chowder_grasp_3.pcd
# object pose equal
# object_41_progresso_new_england_clam_chowder_grasp_3.pcd
# object_41_progresso_new_england_clam_chowder_grasp_5.pcd
# object pose equal
# object_41_progresso_new_england_clam_chowder_grasp_5.pcd
# object_41_progresso_new_england_clam_chowder_grasp_7.pcd
# object_42_progresso_new_england_clam_chowder_grasp_0.pcd
# object pose equal
# object_42_progresso_new_england_clam_chowder_grasp_0.pcd
# object_42_progresso_new_england_clam_chowder_grasp_2.pcd
# object pose equal
# object_42_progresso_new_england_clam_chowder_grasp_2.pcd
# object_42_progresso_new_england_clam_chowder_grasp_4.pcd
# object_42_progresso_new_england_clam_chowder_grasp_5.pcd
# object pose equal
# object_42_progresso_new_england_clam_chowder_grasp_5.pcd
# object_42_progresso_new_england_clam_chowder_grasp_7.pcd
# object pose equal
# object_42_progresso_new_england_clam_chowder_grasp_7.pcd
# object_42_progresso_new_england_clam_chowder_grasp_9.pcd
# object pose equal
# object_42_progresso_new_england_clam_chowder_grasp_9.pcd
# object_42_progresso_new_england_clam_chowder_grasp_11.pcd
# object pose equal
# object_42_progresso_new_england_clam_chowder_grasp_11.pcd
# object_43_quaker_big_chewy_chocolate_chip_grasp_0.pcd
# object_43_quaker_big_chewy_chocolate_chip_grasp_1.pcd
# object pose equal
# object_43_quaker_big_chewy_chocolate_chip_grasp_1.pcd
# object_43_quaker_big_chewy_chocolate_chip_grasp_3.pcd
# object pose equal
# object_43_quaker_big_chewy_chocolate_chip_grasp_3.pcd
# object_43_quaker_big_chewy_chocolate_chip_grasp_5.pcd
# object_43_quaker_big_chewy_chocolate_chip_grasp_6.pcd
# object_43_quaker_big_chewy_chocolate_chip_grasp_7.pcd
# object_43_quaker_big_chewy_chocolate_chip_grasp_8.pcd
# object_44_quaker_big_chewy_peanut_butter_chocolate_chip_grasp_0.pcd
# object_44_quaker_big_chewy_peanut_butter_chocolate_chip_grasp_1.pcd
# object_44_quaker_big_chewy_peanut_butter_chocolate_chip_grasp_2.pcd
# object_45_quaker_chewy_chocolate_chip_grasp_0.pcd
# object_45_quaker_chewy_chocolate_chip_grasp_1.pcd
# object pose equal
# object_45_quaker_chewy_chocolate_chip_grasp_1.pcd
# object_45_quaker_chewy_chocolate_chip_grasp_3.pcd
# object_45_quaker_chewy_chocolate_chip_grasp_4.pcd
# object pose equal
# object_45_quaker_chewy_chocolate_chip_grasp_4.pcd
# object pose equal
# object_45_quaker_chewy_chocolate_chip_grasp_4.pcd
# object_45_quaker_chewy_chocolate_chip_grasp_7.pcd
# object pose equal
# object_45_quaker_chewy_chocolate_chip_grasp_7.pcd
# object_45_quaker_chewy_chocolate_chip_grasp_9.pcd
# object_46_quaker_chewy_dipps_peanut_butter_chocolate_grasp_0.pcd
# object_46_quaker_chewy_dipps_peanut_butter_chocolate_grasp_1.pcd
# object pose equal
# object_46_quaker_chewy_dipps_peanut_butter_chocolate_grasp_1.pcd
# object pose equal
# object_46_quaker_chewy_dipps_peanut_butter_chocolate_grasp_1.pcd
# object_46_quaker_chewy_dipps_peanut_butter_chocolate_grasp_4.pcd
# object_47_quaker_chewy_low_fat_chocolate_chunk_grasp_0.pcd
# object pose equal
# object_47_quaker_chewy_low_fat_chocolate_chunk_grasp_0.pcd
# object_47_quaker_chewy_low_fat_chocolate_chunk_grasp_2.pcd
# object_47_quaker_chewy_low_fat_chocolate_chunk_grasp_3.pcd
# object pose equal
# object_47_quaker_chewy_low_fat_chocolate_chunk_grasp_3.pcd
# object_48_quaker_chewy_peanut_butter_grasp_0.pcd
# object_48_quaker_chewy_peanut_butter_grasp_1.pcd
# object_48_quaker_chewy_peanut_butter_grasp_2.pcd
# object pose equal
# object_48_quaker_chewy_peanut_butter_grasp_2.pcd
# object_48_quaker_chewy_peanut_butter_grasp_4.pcd
# object pose equal
# object_48_quaker_chewy_peanut_butter_grasp_4.pcd
# object_48_quaker_chewy_peanut_butter_grasp_6.pcd
# object pose equal
# object_48_quaker_chewy_peanut_butter_grasp_6.pcd
# object_48_quaker_chewy_peanut_butter_grasp_8.pcd
# object pose equal
# object_48_quaker_chewy_peanut_butter_grasp_8.pcd
# object_48_quaker_chewy_peanut_butter_grasp_10.pcd
# object pose equal
# object_48_quaker_chewy_peanut_butter_grasp_10.pcd
# object_48_quaker_chewy_peanut_butter_grasp_12.pcd
# object pose equal
# object_48_quaker_chewy_peanut_butter_grasp_12.pcd
# object_49_quaker_chewy_peanut_butter_chocolate_chip_grasp_0.pcd
# object pose equal
# object_49_quaker_chewy_peanut_butter_chocolate_chip_grasp_0.pcd
# object_49_quaker_chewy_peanut_butter_chocolate_chip_grasp_2.pcd
# object_49_quaker_chewy_peanut_butter_chocolate_chip_grasp_3.pcd
# object_49_quaker_chewy_peanut_butter_chocolate_chip_grasp_4.pcd
# object pose equal
# object_49_quaker_chewy_peanut_butter_chocolate_chip_grasp_4.pcd
# object_49_quaker_chewy_peanut_butter_chocolate_chip_grasp_6.pcd
# object pose equal
# object_49_quaker_chewy_peanut_butter_chocolate_chip_grasp_6.pcd
# object_49_quaker_chewy_peanut_butter_chocolate_chip_grasp_8.pcd
# object pose equal
# object_49_quaker_chewy_peanut_butter_chocolate_chip_grasp_8.pcd
# object_50_quaker_chewy_smores_grasp_0.pcd
# object_50_quaker_chewy_smores_grasp_1.pcd
# object_50_quaker_chewy_smores_grasp_2.pcd
# object_50_quaker_chewy_smores_grasp_3.pcd
# object_50_quaker_chewy_smores_grasp_4.pcd
# object pose equal
# object_50_quaker_chewy_smores_grasp_4.pcd
# object_51_red_bull_grasp_0.pcd
# object_51_red_bull_grasp_1.pcd
# object_51_red_bull_grasp_2.pcd
# object pose equal
# object_51_red_bull_grasp_2.pcd
# object_51_red_bull_grasp_4.pcd
# object pose equal
# object_51_red_bull_grasp_4.pcd
# object_51_red_bull_grasp_6.pcd
# object_51_red_bull_grasp_7.pcd
# object pose equal
# object_51_red_bull_grasp_7.pcd
# object_51_red_bull_grasp_9.pcd
# object_52_red_cup_grasp_0.pcd
# object_52_red_cup_grasp_1.pcd
# object pose equal
# object_52_red_cup_grasp_1.pcd
# object_52_red_cup_grasp_3.pcd
# object pose equal
# object_52_red_cup_grasp_3.pcd
# object_52_red_cup_grasp_5.pcd
# object pose equal
# object_52_red_cup_grasp_5.pcd
# object_52_red_cup_grasp_7.pcd
# object pose equal
# object_52_red_cup_grasp_7.pcd
# object_52_red_cup_grasp_9.pcd
# object pose equal
# object_52_red_cup_grasp_9.pcd
# object_52_red_cup_grasp_11.pcd
# object_53_ritz_crackers_grasp_0.pcd
# object pose equal
# object_53_ritz_crackers_grasp_0.pcd
# object_53_ritz_crackers_grasp_2.pcd
# object_54_softsoap_gold_grasp_0.pcd
# object pose equal
# object_54_softsoap_gold_grasp_0.pcd
# object_54_softsoap_gold_grasp_2.pcd
# object pose equal
# object_54_softsoap_gold_grasp_2.pcd
# object_54_softsoap_gold_grasp_4.pcd
# object_54_softsoap_gold_grasp_5.pcd
# object pose equal
# object_54_softsoap_gold_grasp_5.pcd
# object pose equal
# object_54_softsoap_gold_grasp_5.pcd
# object_55_softsoap_white_grasp_0.pcd
# object pose equal
# object_55_softsoap_white_grasp_0.pcd
# object pose equal
# object_55_softsoap_white_grasp_0.pcd
# object_55_softsoap_white_grasp_3.pcd
# object_55_softsoap_white_grasp_4.pcd
# object pose equal
# object_55_softsoap_white_grasp_4.pcd
# object pose equal
# object_55_softsoap_white_grasp_4.pcd
# object_55_softsoap_white_grasp_7.pcd
# object_55_softsoap_white_grasp_8.pcd
# object_55_softsoap_white_grasp_9.pcd
# object pose equal
# object_55_softsoap_white_grasp_9.pcd
# object_55_softsoap_white_grasp_11.pcd
# object_56_crest_complete_minty_fresh_grasp_0.pcd
# object pose equal
# object_56_crest_complete_minty_fresh_grasp_0.pcd
# object_56_crest_complete_minty_fresh_grasp_2.pcd
# object pose equal
# object_56_crest_complete_minty_fresh_grasp_2.pcd
# object_56_crest_complete_minty_fresh_grasp_4.pcd
# object_56_crest_complete_minty_fresh_grasp_5.pcd
# object_56_crest_complete_minty_fresh_grasp_6.pcd
# object_56_crest_complete_minty_fresh_grasp_7.pcd
# object_56_crest_complete_minty_fresh_grasp_8.pcd
# object_56_crest_complete_minty_fresh_grasp_9.pcd
# object_57_crystal_hot_sauce_grasp_0.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_0.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_0.pcd
# object_57_crystal_hot_sauce_grasp_3.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_3.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_3.pcd
# object_57_crystal_hot_sauce_grasp_6.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_6.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_6.pcd
# object_57_crystal_hot_sauce_grasp_9.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_9.pcd
# object_57_crystal_hot_sauce_grasp_11.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_11.pcd
# object_57_crystal_hot_sauce_grasp_13.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_13.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_13.pcd
# object_57_crystal_hot_sauce_grasp_16.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_16.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_16.pcd
# object_57_crystal_hot_sauce_grasp_19.pcd
# object pose equal
# object_57_crystal_hot_sauce_grasp_19.pcd
# object_58_cup_noodles_shrimp_picante_grasp_0.pcd
# object pose equal
# object_58_cup_noodles_shrimp_picante_grasp_0.pcd
# object_58_cup_noodles_shrimp_picante_grasp_2.pcd
# object pose equal
# object_58_cup_noodles_shrimp_picante_grasp_2.pcd
# object_58_cup_noodles_shrimp_picante_grasp_4.pcd
# object_58_cup_noodles_shrimp_picante_grasp_5.pcd
# object_58_cup_noodles_shrimp_picante_grasp_6.pcd
# object pose equal
# object_58_cup_noodles_shrimp_picante_grasp_6.pcd
# object_58_cup_noodles_shrimp_picante_grasp_8.pcd
# object pose equal
# object_58_cup_noodles_shrimp_picante_grasp_8.pcd
# object_59_detergent_grasp_0.pcd
# object pose equal
# object_59_detergent_grasp_0.pcd
# object_59_detergent_grasp_2.pcd
# object pose equal
# object_59_detergent_grasp_2.pcd
# object pose equal
# object_59_detergent_grasp_2.pcd
# object_59_detergent_grasp_5.pcd
# object pose equal
# object_59_detergent_grasp_5.pcd
# object_59_detergent_grasp_7.pcd
# object_59_detergent_grasp_8.pcd
# object_59_detergent_grasp_9.pcd
# object_60_dove_beauty_cream_bar_grasp_0.pcd
# object_60_dove_beauty_cream_bar_grasp_1.pcd
# object_60_dove_beauty_cream_bar_grasp_2.pcd
# object pose equal
# object_60_dove_beauty_cream_bar_grasp_2.pcd
# object pose equal
# object_60_dove_beauty_cream_bar_grasp_2.pcd
# object_60_dove_beauty_cream_bar_grasp_5.pcd
# object_60_dove_beauty_cream_bar_grasp_6.pcd
# object_61_dove_go_fresh_burst_grasp_0.pcd
# object_61_dove_go_fresh_burst_grasp_1.pcd
# object_62_dove_pink_grasp_0.pcd
# object_62_dove_pink_grasp_1.pcd
# object_62_dove_pink_grasp_2.pcd
# object_63_eating_right_for_healthy_living_apple_grasp_0.pcd
# object_63_eating_right_for_healthy_living_apple_grasp_1.pcd
# object_63_eating_right_for_healthy_living_apple_grasp_2.pcd
# object_63_eating_right_for_healthy_living_apple_grasp_3.pcd
# object_64_eating_right_for_healthy_living_blueberry_grasp_0.pcd
# object_64_eating_right_for_healthy_living_blueberry_grasp_1.pcd
# object_64_eating_right_for_healthy_living_blueberry_grasp_2.pcd
# object_64_eating_right_for_healthy_living_blueberry_grasp_3.pcd
# object_65_eating_right_for_healthy_living_mixed_berry_grasp_0.pcd
# object_66_eating_right_for_healthy_living_raspberry_grasp_0.pcd
# object_66_eating_right_for_healthy_living_raspberry_grasp_1.pcd
# object_66_eating_right_for_healthy_living_raspberry_grasp_2.pcd
# object pose equal
# object_66_eating_right_for_healthy_living_raspberry_grasp_2.pcd
# object_67_expo_marker_red_grasp_0.pcd
# object_67_expo_marker_red_grasp_1.pcd
# object_68_fruit_by_the_foot_grasp_0.pcd
# object_68_fruit_by_the_foot_grasp_1.pcd
# object_68_fruit_by_the_foot_grasp_2.pcd
# object pose equal
# object_68_fruit_by_the_foot_grasp_2.pcd
# object_68_fruit_by_the_foot_grasp_4.pcd
# object_68_fruit_by_the_foot_grasp_5.pcd
# object pose equal
# object_68_fruit_by_the_foot_grasp_5.pcd
# object_68_fruit_by_the_foot_grasp_7.pcd
# object pose equal
# object_68_fruit_by_the_foot_grasp_7.pcd
# object_68_fruit_by_the_foot_grasp_9.pcd
# object_69_fruit_by_the_foot_grasp_0.pcd
# object_69_fruit_by_the_foot_grasp_1.pcd
# object_69_fruit_by_the_foot_grasp_2.pcd
# object_69_fruit_by_the_foot_grasp_3.pcd
# object pose equal
# object_69_fruit_by_the_foot_grasp_3.pcd
# object_69_fruit_by_the_foot_grasp_5.pcd
# object_69_fruit_by_the_foot_grasp_6.pcd
# object_69_fruit_by_the_foot_grasp_7.pcd
# object_70_gushers_tropical_flavors_grasp_0.pcd
# object_70_gushers_tropical_flavors_grasp_1.pcd
# object_70_gushers_tropical_flavors_grasp_2.pcd
# object_70_gushers_tropical_flavors_grasp_3.pcd
# object_70_gushers_tropical_flavors_grasp_4.pcd
# object_70_gushers_tropical_flavors_grasp_5.pcd
# object pose equal
# object_70_gushers_tropical_flavors_grasp_5.pcd
# object_71_crayola_yellow_green_grasp_0.pcd
# object_71_crayola_yellow_green_grasp_1.pcd
# object pose equal
# object_71_crayola_yellow_green_grasp_1.pcd
# object_71_crayola_yellow_green_grasp_3.pcd
# object_71_crayola_yellow_green_grasp_4.pcd
# object_71_crayola_yellow_green_grasp_5.pcd
# object_71_crayola_yellow_green_grasp_6.pcd
# object_72_haagen_dazs_butter_pecan_grasp_0.pcd
# object pose equal
# object_72_haagen_dazs_butter_pecan_grasp_0.pcd
# object_72_haagen_dazs_butter_pecan_grasp_2.pcd
# object_72_haagen_dazs_butter_pecan_grasp_3.pcd
# object_72_haagen_dazs_butter_pecan_grasp_4.pcd
# object_73_motts_original_assorted_fruit_grasp_0.pcd
# object pose equal
# object_73_motts_original_assorted_fruit_grasp_0.pcd
# object_73_motts_original_assorted_fruit_grasp_2.pcd
# object pose equal
# object_73_motts_original_assorted_fruit_grasp_2.pcd
# object_74_nutrigrain_fruit_crunch_apple_cobbler_grasp_0.pcd
# object_74_nutrigrain_fruit_crunch_apple_cobbler_grasp_1.pcd
# object pose equal
# object_74_nutrigrain_fruit_crunch_apple_cobbler_grasp_1.pcd
# object_74_nutrigrain_fruit_crunch_apple_cobbler_grasp_3.pcd
# object_74_nutrigrain_fruit_crunch_apple_cobbler_grasp_4.pcd
# object_74_nutrigrain_fruit_crunch_apple_cobbler_grasp_5.pcd
# object_75_pop_secret_light_butter_grasp_0.pcd
# object_76_south_beach_good_to_go_dark_chocolate_grasp_0.pcd
# object_76_south_beach_good_to_go_dark_chocolate_grasp_1.pcd
# object_76_south_beach_good_to_go_dark_chocolate_grasp_2.pcd
# object pose equal
# object_76_south_beach_good_to_go_dark_chocolate_grasp_2.pcd
# object_77_south_beach_good_to_go_peanut_butter_grasp_0.pcd
# object_77_south_beach_good_to_go_peanut_butter_grasp_1.pcd
# object_77_south_beach_good_to_go_peanut_butter_grasp_2.pcd
# object_77_south_beach_good_to_go_peanut_butter_grasp_3.pcd
# object_77_south_beach_good_to_go_peanut_butter_grasp_4.pcd
# object_78_spam_grasp_0.pcd
# object_78_spam_grasp_1.pcd
# object_78_spam_grasp_2.pcd
# object_79_spongebob_squarepants_fruit_snaks_grasp_0.pcd
# object_79_spongebob_squarepants_fruit_snaks_grasp_1.pcd
# object pose equal
# object_79_spongebob_squarepants_fruit_snaks_grasp_1.pcd
# object_79_spongebob_squarepants_fruit_snaks_grasp_3.pcd
# object pose equal
# object_79_spongebob_squarepants_fruit_snaks_grasp_3.pcd
# object_79_spongebob_squarepants_fruit_snaks_grasp_5.pcd
# object_80_suave_sweet_guava_nectar_body_wash_grasp_0.pcd
# object_80_suave_sweet_guava_nectar_body_wash_grasp_1.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_1.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_1.pcd
# object_80_suave_sweet_guava_nectar_body_wash_grasp_4.pcd
# object_80_suave_sweet_guava_nectar_body_wash_grasp_5.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_5.pcd
# object_80_suave_sweet_guava_nectar_body_wash_grasp_7.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_7.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_7.pcd
# object_80_suave_sweet_guava_nectar_body_wash_grasp_10.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_10.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_10.pcd
# object_80_suave_sweet_guava_nectar_body_wash_grasp_13.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_13.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_13.pcd
# object_80_suave_sweet_guava_nectar_body_wash_grasp_16.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_16.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_16.pcd
# object_80_suave_sweet_guava_nectar_body_wash_grasp_19.pcd
# object pose equal
# object_80_suave_sweet_guava_nectar_body_wash_grasp_19.pcd
# object_81_sunkist_fruit_snacks_mixed_fruit_grasp_0.pcd
# object pose equal
# object_81_sunkist_fruit_snacks_mixed_fruit_grasp_0.pcd
# object_81_sunkist_fruit_snacks_mixed_fruit_grasp_2.pcd
# object_81_sunkist_fruit_snacks_mixed_fruit_grasp_3.pcd
# object_81_sunkist_fruit_snacks_mixed_fruit_grasp_4.pcd
# object_82_tapatio_hot_sauce_grasp_0.pcd
# object pose equal
# object_82_tapatio_hot_sauce_grasp_0.pcd
# object pose equal
# object_82_tapatio_hot_sauce_grasp_0.pcd
# object_82_tapatio_hot_sauce_grasp_3.pcd
# object pose equal
# object_82_tapatio_hot_sauce_grasp_3.pcd
# object pose equal
# object_82_tapatio_hot_sauce_grasp_3.pcd
# object_82_tapatio_hot_sauce_grasp_6.pcd
# object pose equal
# object_82_tapatio_hot_sauce_grasp_6.pcd
# object pose equal
# object_82_tapatio_hot_sauce_grasp_6.pcd
# object_82_tapatio_hot_sauce_grasp_9.pcd
# object_82_tapatio_hot_sauce_grasp_10.pcd
# object pose equal
# object_82_tapatio_hot_sauce_grasp_10.pcd
# object pose equal
# object_82_tapatio_hot_sauce_grasp_10.pcd
# object_83_v8_fusion_peach_mango_grasp_0.pcd
# object pose equal
# object_83_v8_fusion_peach_mango_grasp_0.pcd
# object_83_v8_fusion_peach_mango_grasp_2.pcd
# object_83_v8_fusion_peach_mango_grasp_3.pcd
# object_83_v8_fusion_peach_mango_grasp_4.pcd
# object_83_v8_fusion_peach_mango_grasp_5.pcd
# object pose equal
# object_83_v8_fusion_peach_mango_grasp_5.pcd
# object_84_v8_fusion_strawberry_banana_grasp_0.pcd
# object_84_v8_fusion_strawberry_banana_grasp_1.pcd
# object pose equal
# object_84_v8_fusion_strawberry_banana_grasp_1.pcd
# object_84_v8_fusion_strawberry_banana_grasp_3.pcd
# object pose equal
# object_84_v8_fusion_strawberry_banana_grasp_3.pcd
# object_84_v8_fusion_strawberry_banana_grasp_5.pcd
# object pose equal
# object_84_v8_fusion_strawberry_banana_grasp_5.pcd
# object_85_vo5_extra_body_volumizing_shampoo_grasp_0.pcd
# object_85_vo5_extra_body_volumizing_shampoo_grasp_1.pcd
# object_85_vo5_extra_body_volumizing_shampoo_grasp_2.pcd
# object pose equal
# object_85_vo5_extra_body_volumizing_shampoo_grasp_2.pcd
# object pose equal
# object_85_vo5_extra_body_volumizing_shampoo_grasp_2.pcd
# object_85_vo5_extra_body_volumizing_shampoo_grasp_5.pcd
# object pose equal
# object_85_vo5_extra_body_volumizing_shampoo_grasp_5.pcd
# object pose equal
# object_85_vo5_extra_body_volumizing_shampoo_grasp_5.pcd
# object_85_vo5_extra_body_volumizing_shampoo_grasp_8.pcd
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_0.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_0.pcd
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_2.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_2.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_2.pcd
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_5.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_5.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_5.pcd
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_8.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_8.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_8.pcd
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_11.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_11.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_11.pcd
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_14.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_14.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_14.pcd
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_17.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_17.pcd
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_19.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_19.pcd
# object pose equal
# object_86_vo5_split_ends_anti_breakage_shampoo_grasp_19.pcd
# object_87_vo5_tea_therapy_healthful_green_tea_smoothing_shampoo_grasp_0.pcd
# object pose equal
# object_87_vo5_tea_therapy_healthful_green_tea_smoothing_shampoo_grasp_0.pcd
# object_87_vo5_tea_therapy_healthful_green_tea_smoothing_shampoo_grasp_2.pcd
# object_87_vo5_tea_therapy_healthful_green_tea_smoothing_shampoo_grasp_3.pcd
# object_87_vo5_tea_therapy_healthful_green_tea_smoothing_shampoo_grasp_4.pcd
# object pose equal
# object_87_vo5_tea_therapy_healthful_green_tea_smoothing_shampoo_grasp_4.pcd
# object pose equal
# object_87_vo5_tea_therapy_healthful_green_tea_smoothing_shampoo_grasp_4.pcd
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_0.pcd
# object pose equal
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_0.pcd
# object pose equal
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_0.pcd
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_3.pcd
# object pose equal
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_3.pcd
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_5.pcd
# object pose equal
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_5.pcd
# object pose equal
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_5.pcd
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_8.pcd
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_9.pcd
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_10.pcd
# object pose equal
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_10.pcd
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_12.pcd
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_13.pcd
# object pose equal
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_13.pcd
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_15.pcd
# object_88_white_rain_sensations_apple_blossom_hydrating_body_wash_grasp_16.pcd
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_0.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_0.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_0.pcd
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_3.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_3.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_3.pcd
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_6.pcd
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_7.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_7.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_7.pcd
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_10.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_10.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_10.pcd
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_13.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_13.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_13.pcd
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_16.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_16.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_16.pcd
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_19.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_19.pcd
# object pose equal
# object_89_white_rain_sensations_ocean_mist_hydrating_body_wash_grasp_19.pcd
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_0.pcd
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_1.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_1.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_1.pcd
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_4.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_4.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_4.pcd
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_7.pcd
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_8.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_8.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_8.pcd
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_11.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_11.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_11.pcd
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_14.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_14.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_14.pcd
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_17.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_17.pcd
# object pose equal
# object_90_white_rain_sensations_ocean_mist_hydrating_conditioner_grasp_17.pcd
# object_91_zilla_night_black_heat_grasp_0.pcd
# object pose equal
# object_91_zilla_night_black_heat_grasp_0.pcd
# object_91_zilla_night_black_heat_grasp_2.pcd
# object pose equal
# object_91_zilla_night_black_heat_grasp_2.pcd
# object_91_zilla_night_black_heat_grasp_4.pcd
# object pose equal
# object_91_zilla_night_black_heat_grasp_4.pcd
# object_91_zilla_night_black_heat_grasp_6.pcd
# object_91_zilla_night_black_heat_grasp_7.pcd
# object pose equal
# object_91_zilla_night_black_heat_grasp_7.pcd
# object pose equal
# object_91_zilla_night_black_heat_grasp_7.pcd
# object_92_nutrigrain_fruit_crunch_strawberry_parfait_grasp_0.pcd
# object_92_nutrigrain_fruit_crunch_strawberry_parfait_grasp_1.pcd
# object_93_nutrigrain_harvest_blueberry_bliss_grasp_0.pcd
# object_94_nutrigrain_harvest_country_strawberry_grasp_0.pcd
# object_95_nutrigrain_raspberry_grasp_0.pcd
# object_95_nutrigrain_raspberry_grasp_1.pcd
# object_95_nutrigrain_raspberry_grasp_2.pcd
# object_95_nutrigrain_raspberry_grasp_3.pcd
# object_96_nutrigrain_strawberry_grasp_0.pcd
# object_96_nutrigrain_strawberry_grasp_1.pcd
# object_96_nutrigrain_strawberry_grasp_2.pcd
# object_96_nutrigrain_strawberry_grasp_3.pcd
# object_96_nutrigrain_strawberry_grasp_4.pcd
# object pose equal
# object_96_nutrigrain_strawberry_grasp_4.pcd
# object_96_nutrigrain_strawberry_grasp_6.pcd
# object_97_nutrigrain_strawberry_greek_yogurt_grasp_0.pcd
# object_97_nutrigrain_strawberry_greek_yogurt_grasp_1.pcd
# object_97_nutrigrain_strawberry_greek_yogurt_grasp_2.pcd
# object pose equal
# object_97_nutrigrain_strawberry_greek_yogurt_grasp_2.pcd
# object_97_nutrigrain_strawberry_greek_yogurt_grasp_4.pcd
# object_98_paper_cup_holder_grasp_0.pcd
# object_98_paper_cup_holder_grasp_1.pcd
# object pose equal
# object_98_paper_cup_holder_grasp_1.pcd
# object_98_paper_cup_holder_grasp_3.pcd
# object pose equal
# object_98_paper_cup_holder_grasp_3.pcd
# object pose equal
# object_98_paper_cup_holder_grasp_3.pcd
# object_98_paper_cup_holder_grasp_6.pcd
# object pose equal
# object_98_paper_cup_holder_grasp_6.pcd
# object_98_paper_cup_holder_grasp_8.pcd
# object pose equal
# object_98_paper_cup_holder_grasp_8.pcd
# object_99_paper_plate_grasp_0.pcd
# object_99_paper_plate_grasp_1.pcd
# object_99_paper_plate_grasp_2.pcd
# object_99_paper_plate_grasp_3.pcd
# object_99_paper_plate_grasp_4.pcd
# object_99_paper_plate_grasp_5.pcd
# object_100_pepto_bismol_grasp_0.pcd
# object pose equal
# object_100_pepto_bismol_grasp_0.pcd
# object pose equal
# object_100_pepto_bismol_grasp_0.pcd
# object_100_pepto_bismol_grasp_3.pcd
# object pose equal
# object_100_pepto_bismol_grasp_3.pcd
# object_100_pepto_bismol_grasp_5.pcd
# object pose equal
# object_100_pepto_bismol_grasp_5.pcd
# object pose equal
# object_100_pepto_bismol_grasp_5.pcd
# object_100_pepto_bismol_grasp_8.pcd
# object pose equal
# object_100_pepto_bismol_grasp_8.pcd
# object_100_pepto_bismol_grasp_10.pcd
# object pose equal
# object_100_pepto_bismol_grasp_10.pcd
# object_100_pepto_bismol_grasp_12.pcd
# object pose equal
# object_100_pepto_bismol_grasp_12.pcd
# object_100_pepto_bismol_grasp_14.pcd
# object_100_pepto_bismol_grasp_15.pcd
# object pose equal
# object_100_pepto_bismol_grasp_15.pcd
# object pose equal
# object_100_pepto_bismol_grasp_15.pcd
# object_100_pepto_bismol_grasp_18.pcd
# object pose equal
# object_100_pepto_bismol_grasp_18.pcd
# object_101_pop_secret_butter_grasp_0.pcd
# object pose equal
# object_101_pop_secret_butter_grasp_0.pcd
# object pose equal
# object_101_pop_secret_butter_grasp_0.pcd
# object_101_pop_secret_butter_grasp_3.pcd
# object pose equal
# object_101_pop_secret_butter_grasp_3.pcd
# object pose equal
# object_101_pop_secret_butter_grasp_3.pcd
# object_101_pop_secret_butter_grasp_6.pcd
# object pose equal
# object_101_pop_secret_butter_grasp_6.pcd
# object_101_pop_secret_butter_grasp_8.pcd
# object pose equal
# object_101_pop_secret_butter_grasp_8.pcd
# object_101_pop_secret_butter_grasp_10.pcd
# object_101_pop_secret_butter_grasp_11.pcd
# object pose equal
# object_101_pop_secret_butter_grasp_11.pcd
# object_101_pop_secret_butter_grasp_13.pcd
# object pose equal
# object_101_pop_secret_butter_grasp_13.pcd
# object_101_pop_secret_butter_grasp_15.pcd
# object pose equal
# object_101_pop_secret_butter_grasp_15.pcd
# object_101_pop_secret_butter_grasp_17.pcd
# object pose equal
# object_101_pop_secret_butter_grasp_17.pcd
# object_101_pop_secret_butter_grasp_19.pcd
# object pose equal
# object_101_pop_secret_butter_grasp_19.pcd
# object_102_haagen_dazs_cookie_dough_grasp_0.pcd
# object pose equal
# object_102_haagen_dazs_cookie_dough_grasp_0.pcd
# object_102_haagen_dazs_cookie_dough_grasp_2.pcd
# object pose equal
# object_102_haagen_dazs_cookie_dough_grasp_2.pcd
# object_102_haagen_dazs_cookie_dough_grasp_4.pcd
# object_102_haagen_dazs_cookie_dough_grasp_5.pcd
# object_102_haagen_dazs_cookie_dough_grasp_6.pcd
# object pose equal
# object_102_haagen_dazs_cookie_dough_grasp_6.pcd
# object_102_haagen_dazs_cookie_dough_grasp_8.pcd
# object_102_haagen_dazs_cookie_dough_grasp_9.pcd
# object_102_haagen_dazs_cookie_dough_grasp_10.pcd
# object pose equal
# object_102_haagen_dazs_cookie_dough_grasp_10.pcd
# object_102_haagen_dazs_cookie_dough_grasp_12.pcd
# object pose equal
# object_102_haagen_dazs_cookie_dough_grasp_12.pcd
# object_102_haagen_dazs_cookie_dough_grasp_14.pcd
# object pose equal
# object_102_haagen_dazs_cookie_dough_grasp_14.pcd
# object_102_haagen_dazs_cookie_dough_grasp_16.pcd
# object pose equal
# object_102_haagen_dazs_cookie_dough_grasp_16.pcd
# object_102_haagen_dazs_cookie_dough_grasp_18.pcd
# object pose equal
# object_102_haagen_dazs_cookie_dough_grasp_18.pcd
# object_103_hersheys_cocoa_grasp_0.pcd
# object pose equal
# object_103_hersheys_cocoa_grasp_0.pcd
# object_103_hersheys_cocoa_grasp_2.pcd
# object_103_hersheys_cocoa_grasp_3.pcd
# object_103_hersheys_cocoa_grasp_4.pcd
# object_103_hersheys_cocoa_grasp_5.pcd
# object_103_hersheys_cocoa_grasp_6.pcd
# object_103_hersheys_cocoa_grasp_7.pcd
# object_103_hersheys_cocoa_grasp_8.pcd
# object_104_honey_bunches_of_oats_honey_roasted_grasp_0.pcd
# object pose equal
# object_104_honey_bunches_of_oats_honey_roasted_grasp_0.pcd
# object_104_honey_bunches_of_oats_honey_roasted_grasp_2.pcd
# object pose equal
# object_104_honey_bunches_of_oats_honey_roasted_grasp_2.pcd
# object pose equal
# object_104_honey_bunches_of_oats_honey_roasted_grasp_2.pcd
# object_104_honey_bunches_of_oats_honey_roasted_grasp_5.pcd
# object pose equal
# object_104_honey_bunches_of_oats_honey_roasted_grasp_5.pcd
# object_104_honey_bunches_of_oats_honey_roasted_grasp_7.pcd
# object pose equal
# object_104_honey_bunches_of_oats_honey_roasted_grasp_7.pcd
# object_104_honey_bunches_of_oats_honey_roasted_grasp_9.pcd
# object_104_honey_bunches_of_oats_honey_roasted_grasp_10.pcd
# object pose equal
# object_104_honey_bunches_of_oats_honey_roasted_grasp_10.pcd
# object pose equal
# object_104_honey_bunches_of_oats_honey_roasted_grasp_10.pcd
# object_105_honey_bunches_of_oats_with_almonds_grasp_0.pcd
# object pose equal
# object_105_honey_bunches_of_oats_with_almonds_grasp_0.pcd
# object_105_honey_bunches_of_oats_with_almonds_grasp_2.pcd
# object pose equal
# object_105_honey_bunches_of_oats_with_almonds_grasp_2.pcd
# object_105_honey_bunches_of_oats_with_almonds_grasp_4.pcd
# object_105_honey_bunches_of_oats_with_almonds_grasp_5.pcd
# object pose equal
# object_105_honey_bunches_of_oats_with_almonds_grasp_5.pcd
# object pose equal
# object_105_honey_bunches_of_oats_with_almonds_grasp_5.pcd
# object_105_honey_bunches_of_oats_with_almonds_grasp_8.pcd
# object_106_hunts_paste_grasp_0.pcd
# object pose equal
# object_106_hunts_paste_grasp_0.pcd
# object_106_hunts_paste_grasp_2.pcd
# object_106_hunts_paste_grasp_3.pcd
# object_106_hunts_paste_grasp_4.pcd
# object_106_hunts_paste_grasp_5.pcd
# object_106_hunts_paste_grasp_6.pcd
# object pose equal
# object_106_hunts_paste_grasp_6.pcd
# object_107_hunts_sauce_grasp_0.pcd
# object_107_hunts_sauce_grasp_1.pcd
# object_107_hunts_sauce_grasp_2.pcd
# object_107_hunts_sauce_grasp_3.pcd
# object pose equal
# object_107_hunts_sauce_grasp_3.pcd
# object_107_hunts_sauce_grasp_5.pcd
# object pose equal
# object_107_hunts_sauce_grasp_5.pcd
# object_107_hunts_sauce_grasp_7.pcd
# object_107_hunts_sauce_grasp_8.pcd
# object_107_hunts_sauce_grasp_9.pcd
# object pose equal
# object_107_hunts_sauce_grasp_9.pcd
# object_107_hunts_sauce_grasp_11.pcd
# object pose equal
# object_107_hunts_sauce_grasp_11.pcd
# object_107_hunts_sauce_grasp_13.pcd
# object pose equal
# object_107_hunts_sauce_grasp_13.pcd
# object_108_ikea_table_leg_blue_grasp_0.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_0.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_0.pcd
# object_108_ikea_table_leg_blue_grasp_3.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_3.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_3.pcd
# object_108_ikea_table_leg_blue_grasp_6.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_6.pcd
# object_108_ikea_table_leg_blue_grasp_8.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_8.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_8.pcd
# object_108_ikea_table_leg_blue_grasp_11.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_11.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_11.pcd
# object_108_ikea_table_leg_blue_grasp_14.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_14.pcd
# object_108_ikea_table_leg_blue_grasp_16.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_16.pcd
# object_108_ikea_table_leg_blue_grasp_18.pcd
# object_108_ikea_table_leg_blue_grasp_19.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_19.pcd
# object pose equal
# object_108_ikea_table_leg_blue_grasp_19.pcd
# object_109_krylon_crystal_clear_grasp_0.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_0.pcd
# object_109_krylon_crystal_clear_grasp_2.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_2.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_2.pcd
# object_109_krylon_crystal_clear_grasp_5.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_5.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_5.pcd
# object_109_krylon_crystal_clear_grasp_8.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_8.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_8.pcd
# object_109_krylon_crystal_clear_grasp_11.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_11.pcd
# object_109_krylon_crystal_clear_grasp_13.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_13.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_13.pcd
# object_109_krylon_crystal_clear_grasp_16.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_16.pcd
# object_109_krylon_crystal_clear_grasp_18.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_18.pcd
# object pose equal
# object_109_krylon_crystal_clear_grasp_18.pcd
# object_110_krylon_low_odor_clear_finish_grasp_0.pcd
# object pose equal
# object_110_krylon_low_odor_clear_finish_grasp_0.pcd
# object pose equal
# object_110_krylon_low_odor_clear_finish_grasp_0.pcd
# object_110_krylon_low_odor_clear_finish_grasp_3.pcd
# object pose equal
# object_110_krylon_low_odor_clear_finish_grasp_3.pcd
# object pose equal
# object_110_krylon_low_odor_clear_finish_grasp_3.pcd
# object_110_krylon_low_odor_clear_finish_grasp_6.pcd
# object pose equal
# object_110_krylon_low_odor_clear_finish_grasp_6.pcd
# object_110_krylon_low_odor_clear_finish_grasp_8.pcd
# object pose equal
# object_110_krylon_low_odor_clear_finish_grasp_8.pcd
# object_110_krylon_low_odor_clear_finish_grasp_10.pcd
# object pose equal
# object_110_krylon_low_odor_clear_finish_grasp_10.pcd
# object pose equal
# object_110_krylon_low_odor_clear_finish_grasp_10.pcd
# object_110_krylon_low_odor_clear_finish_grasp_13.pcd
# object pose equal
# object_110_krylon_low_odor_clear_finish_grasp_13.pcd
# object pose equal
# object_110_krylon_low_odor_clear_finish_grasp_13.pcd
# object_110_krylon_low_odor_clear_finish_grasp_16.pcd
# object_111_krylon_matte_finish_grasp_0.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_0.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_0.pcd
# object_111_krylon_matte_finish_grasp_3.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_3.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_3.pcd
# object_111_krylon_matte_finish_grasp_6.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_6.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_6.pcd
# object_111_krylon_matte_finish_grasp_9.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_9.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_9.pcd
# object_111_krylon_matte_finish_grasp_12.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_12.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_12.pcd
# object_111_krylon_matte_finish_grasp_15.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_15.pcd
# object pose equal
# object_111_krylon_matte_finish_grasp_15.pcd
# object_111_krylon_matte_finish_grasp_18.pcd
# object_111_krylon_matte_finish_grasp_19.pcd
# object_112_krylon_short_cuts_grasp_0.pcd
# object pose equal
# object_112_krylon_short_cuts_grasp_0.pcd
# object_112_krylon_short_cuts_grasp_2.pcd
# object_112_krylon_short_cuts_grasp_3.pcd
# object_112_krylon_short_cuts_grasp_4.pcd
# object_112_krylon_short_cuts_grasp_5.pcd
# object_113_mom_to_mom_butternut_squash_pear_grasp_0.pcd
# object_113_mom_to_mom_butternut_squash_pear_grasp_1.pcd
# object_113_mom_to_mom_butternut_squash_pear_grasp_2.pcd
# object pose equal
# object_113_mom_to_mom_butternut_squash_pear_grasp_2.pcd
# object_113_mom_to_mom_butternut_squash_pear_grasp_4.pcd
# object_113_mom_to_mom_butternut_squash_pear_grasp_5.pcd
# object_113_mom_to_mom_butternut_squash_pear_grasp_6.pcd
# object_113_mom_to_mom_butternut_squash_pear_grasp_7.pcd
# object_113_mom_to_mom_butternut_squash_pear_grasp_8.pcd
# object pose equal
# object_113_mom_to_mom_butternut_squash_pear_grasp_8.pcd
# object pose equal
# object_113_mom_to_mom_butternut_squash_pear_grasp_8.pcd
# object_114_mom_to_mom_sweet_potato_corn_apple_grasp_0.pcd
# object_114_mom_to_mom_sweet_potato_corn_apple_grasp_1.pcd
# object pose equal
# object_114_mom_to_mom_sweet_potato_corn_apple_grasp_1.pcd
# object_114_mom_to_mom_sweet_potato_corn_apple_grasp_3.pcd
# object_114_mom_to_mom_sweet_potato_corn_apple_grasp_4.pcd
# object pose equal
# object_114_mom_to_mom_sweet_potato_corn_apple_grasp_4.pcd
# object_114_mom_to_mom_sweet_potato_corn_apple_grasp_6.pcd
# 967 232 520 76
